# %%
import sqlite3
import pandas as pd

# %%
def load_imdb_database(db_path):
  try:
    conn = sqlite3.connect(db_path)
    print("IMDB database loaded successfully.")
    return conn
  except sqlite3.Error as e:
    print(f"Error loading IMDB database: {e}")
    return None

# %%
db_path = "/content/imdb.db"
conn = load_imdb_database(db_path)

if conn:
  print("Connection successful")
  cursor = conn.cursor()
# Out:
# IMDB database loaded successfully.
# Connection successful

# %%
q1 = "SELECT title, year FROM movie LIMIT 10"
result = pd.read_sql_query(q1, conn)
result
# Out:
#                         title  year
# 0                      Mowgli  2018
# 1               Ocean's Eight  2018
# 2                 Tomb Raider  2018
# 3                The Avengers  2012
# 4                     Tumbbad  2018
# 5                   Kedarnath  2018
# 6  Captain America: Civil War  2016
# 7                   Andhadhun  2018
# 8                        Lion  2016
# 9                Rajma Chawal  2018

# %%
conn = sqlite3.connect("academic.db")
cursor = conn.cursor()

# %%
q2 = """CREATE TABLE students (
    id INT PRIMARY KEY,
    name VARCHAR(50),
    age INT,
    grade CHAR(1)
);"""

# %%
cursor.execute(q2)

# %%
q3 = """INSERT INTO students (id, name, age, grade)
VALUES (1, 'John Doe', 20, 'A');"""

# %%
cursor.execute(q3)

# %%
q4 = "SELECT * FROM students"
result = pd.read_sql_query(q4, conn)
result
# Out:
#    id      name  age grade
# 0   1  John Doe   20     A

# %%
conn.close()
